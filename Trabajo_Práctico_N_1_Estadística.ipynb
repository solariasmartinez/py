# %% [markdown]
# <a href="https://colab.research.google.com/github/solariasmartinez/py/blob/master/Trabajo_Pr%C3%A1ctico_N_1_Estad%C3%ADstica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Trabajo Integral de Estadística**
#
# Mapa del delito
#
# **ESTUDIO DEL MAPA DEL DELITO**
#
# En base a la información publicada en el portal de la Ciudad, https://data.buenosaires.gob.ar/dataset/delitos se buscar llevar adelante un análisis de los delitos ocurridos en el año 2020.
#
# La información se la puede descargar de:
# https://data.buenosaires.gob.ar/dataset/delitos
#
# Dataset: Delitos 2020
# Fecha límite de entrega: 28/06/2021
#
# ## Exploración inicial de la información
#
# Descargar la información pública y estructurarla de forma tal que se pueda trabajar de forma mas sencilla;
#
# • Explorar cada una de las variables;
# • Normalizar (corregir) los campos;
# • Identificar el dominio de cada variable.
#
# Entender el tipo de variable y cuales son los valores posibles;
#
# ## Análisis por Mes
#
# • Construir una tabla de frecuencias de cantidades de delitos por mes;
# • Calcular las frecuencias absolutas simples y acumuladas, relativas simples y acumuladas;
# • Calcular la media, la mediana, Cuartil 1 y 3, Varianza, Desvío Standard y Coeficiente de Variación por
# mes;
# • Construir un gráfico de líneas por mes y tipo de hurto;
# • Construir un gráfico de cajas y bigotes con las 5 medidas descriptivas;
#
# ## Análisis por Comuna
#
# • Construir una tabla de frecuencias de cantidades de delitos por Comuna;
# • Calcular la media, la mediana, Cuartil 1 y 3, Varianza, Desvío Standard y Coeficiente de Variación por
# comuna;
# • Calcular las frecuencias absolutas simples y relativas simples;
# • Cuales son los 10 barrios con mayor cantidad de delitos?
# • Cuanto representan estos 10, sobre el total de los barrios?
# • Construir un gráfico de columnas de las frecuencias relativas ordenado de forma descendente (de
# mayor a menor)

# %% [markdown]
# **Análisis por franja horaria**

# %% [markdown]
# • Construir una tabla de frecuencias agrupadas en 4 intervalos de clases.
# • Calcular las frecuencias absolutas simples y acumuladas, relativas simples y acumuladas;
# • Calcular la media, la mediana, Cuartil 1 y 3, Varianza, Desvío Standard y Coeficiente de Variación por
# rango horario;
# • Construir un gráfico de circular (torta) en base a la participación de cada franja horaria en el total de
# delitos.

# %% [markdown]
# **Exploración inicial de la información**

# %% [markdown]
# ## Explorar cada una de las variables

# %%
import pandas as pd

# %%
pd.read_csv("delitos_2020.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                id_mapa  anio        mes  ...    latitud   longitud victimas
# 0      HC-2020-0007157  2020      Enero  ... -34.592133 -58.439106      1.0
# 1      HC-2020-0009055  2020      Enero  ... -34.646459 -58.450195      1.0
# 2      HC-2020-0022499  2020      Enero  ... -34.609272 -58.393379      1.0
# 3      HC-2020-0028163  2020      Enero  ... -34.624766 -58.410372      1.0
# 4      HC-2020-0029931  2020      Enero  ... -34.609303 -58.390526      1.0
# ...                ...   ...        ...  ...        ...        ...      ...
# 66709  RH-2021-0005846  2020  Diciembre  ... -34.587304 -58.507352      NaN
# 66710  RH-2021-0006011  2020  Diciembre  ... -34.649130 -58.429858      NaN
# ...

# %%
surveys_df = pd.read_csv("delitos_2020.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
surveys_df
# Out:
#                id_mapa  anio        mes  ...    latitud   longitud victimas
# 0      HC-2020-0007157  2020      Enero  ... -34.592133 -58.439106      1.0
# 1      HC-2020-0009055  2020      Enero  ... -34.646459 -58.450195      1.0
# 2      HC-2020-0022499  2020      Enero  ... -34.609272 -58.393379      1.0
# 3      HC-2020-0028163  2020      Enero  ... -34.624766 -58.410372      1.0
# 4      HC-2020-0029931  2020      Enero  ... -34.609303 -58.390526      1.0
# ...                ...   ...        ...  ...        ...        ...      ...
# 66709  RH-2021-0005846  2020  Diciembre  ... -34.587304 -58.507352      NaN
# 66710  RH-2021-0006011  2020  Diciembre  ... -34.649130 -58.429858      NaN
# 66711  RH-2021-0006016  2020  Diciembre  ... -34.607985 -58.392040      NaN
# 66712  RH-2021-0006309  2020  Diciembre  ... -34.589516 -58.505280      NaN
# 66713  RH-2021-0006423  2020  Diciembre  ... -34.596366 -58.378446      NaN
#
# [66714 rows x 14 columns]

# %%
surveys_df.head()
# Out:
#            id_mapa  anio    mes  ...    latitud   longitud victimas
# 0  HC-2020-0007157  2020  Enero  ... -34.592133 -58.439106      1.0
# 1  HC-2020-0009055  2020  Enero  ... -34.646459 -58.450195      1.0
# 2  HC-2020-0022499  2020  Enero  ... -34.609272 -58.393379      1.0
# 3  HC-2020-0028163  2020  Enero  ... -34.624766 -58.410372      1.0
# 4  HC-2020-0029931  2020  Enero  ... -34.609303 -58.390526      1.0
#
# [5 rows x 14 columns]

# %%
surveys_df.dtypes
# Out:
# id_mapa       object
# anio           int64
# mes           object
# dia           object
# fecha         object
# franja        object
# tipo          object
# subtipo       object
# uso_armas     object
# barrio        object
# comuna       float64
# latitud      float64
# longitud     float64
# victimas     float64
# dtype: object

# %% [markdown]
# ## Normalizar(corregir) los campos

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
